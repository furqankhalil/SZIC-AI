# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('E:\SZIC AI\dataset\Churn_Modelling.csv')
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
data.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.007246   0.000599        0.012044
# CustomerId      -0.012419       0.016972  -0.014025        0.001665
# CreditScore      0.006268       0.012238  -0.005458        0.025651
# Age              0.028308      -0.030680  -0.011721        0.085472
# Tenure          -0.012254       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.304180  -0.014858       -0.010084
# NumOfProducts   -0.304180       1.000000   0.003183        0.009612
# HasCrCard       -0.014858       0.003183   1.000000       -0.011866
# IsActiveMember  -0.010084       0.009612  -0.011866        1.000000
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
# Exited           0.118533      -0.047820  -0.007138       -0.156128
#
#                  EstimatedSalary    Exited
# RowNumber              -0.005988 -0.016571
# CustomerId              0.015271 -0.006248
# CreditScore            -0.001384 -0.027094
# Age                    -0.007201  0.285323
# Tenure                  0.007784 -0.014001
# Balance                 0.012797  0.118533
# NumOfProducts           0.014204 -0.047820
# HasCrCard              -0.009933 -0.007138
# IsActiveMember         -0.011421 -0.156128
# EstimatedSalary         1.000000  0.012097
# Exited                  0.012097  1.000000

# %% [markdown]
# # Data Preprocessing

# %%
y = data[['Exited']]
y.head(3)
# Out:
#    Exited
# 0       1
# 1       0
# 2       1

# %%
data.drop(['RowNumber', 'CustomerId', 'Surname','Exited'],axis = 1,inplace = True)
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
data.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %%
data.Geography.replace(['France','Germany','Spain'],[0,1,2],inplace = True)
data.Gender.replace(['Male','Female'],[0,1],inplace = True)

# %%
data.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

# %%
x = ss.fit_transform(data)

# %%
x
# Out:
# array([[-0.32622142, -0.90188624,  1.09598752, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-0.44003595,  1.51506738,  1.09598752, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.53679418, -0.90188624,  1.09598752, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 0.60498839, -0.90188624,  1.09598752, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.25683526,  0.30659057, -0.91241915, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.46377078, -0.90188624,  1.09598752, ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %%
data
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       1   42       2       0.00              1
# 1             608          2       1   41       1   83807.86              1
# 2             502          0       1   42       8  159660.80              3
# 3             699          0       1   39       1       0.00              2
# 4             850          2       1   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       0   39       5       0.00              2
# 9996          516          0       0   35      10   57369.61              1
# 9997          709          0       1   36       7       0.00              1
# 9998          772          1       0   42       3   75075.31              2
# 9999          792          0       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
shape = x_train
shape.shape
# Out:
# (8000, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# # Building a Neural Network

# %%
model = Sequential()

model.add(Dense(units = 10, input_shape = (10,)))     #Input Layer

model.add(Dense(units = 8, activation = 'relu'))      #Hidden Layer
 
model.add(Dense(units = 1, activation = 'sigmoid'))      #Output Layer

model.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dense_1 (Dense)             (None, 8)                 88
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 207
# Trainable params: 207
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training Model

# %%
history = model.fit(x_train , y_train , validation_split=(0.1) , epochs=50)
# Out:
# Epoch 1/50
# 225/225 [==============================] - 5s 3ms/step - loss: 0.5468 - accuracy: 0.7951 - val_loss: 0.4636 - val_accuracy: 0.8125
# Epoch 2/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.7965 - val_loss: 0.4240 - val_accuracy: 0.8125
# Epoch 3/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.7967 - val_loss: 0.4143 - val_accuracy: 0.8163
# Epoch 4/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4258 - accuracy: 0.8018 - val_loss: 0.4063 - val_accuracy: 0.8213
# Epoch 5/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8139 - val_loss: 0.4004 - val_accuracy: 0.8438
# Epoch 6/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8261 - val_loss: 0.3933 - val_accuracy: 0.8462
# Epoch 7/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8289 - val_loss: 0.3914 - val_accuracy: 0.8487
# Epoch 8/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4087 - accuracy: 0.8315 - val_loss: 0.3848 - val_accuracy: 0.8537
# Epoch 9/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8317 - val_loss: 0.3831 - val_accuracy: 0.8550
# Epoch 10/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8314 - val_loss: 0.3826 - val_accuracy: 0.8525
# Epoch 11/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8328 - val_loss: 0.3815 - val_accuracy: 0.8512
# Epoch 12/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8326 - val_loss: 0.3807 - val_accuracy: 0.8512
# Epoch 13/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8318 - val_loss: 0.3793 - val_accuracy: 0.8487
# Epoch 14/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8322 - val_loss: 0.3783 - val_accuracy: 0.8462
# Epoch 15/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8321 - val_loss: 0.3767 - val_accuracy: 0.8500
# Epoch 16/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8332 - val_loss: 0.3770 - val_accuracy: 0.8487
# Epoch 17/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8344 - val_loss: 0.3758 - val_accuracy: 0.8525
# Epoch 18/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8351 - val_loss: 0.3737 - val_accuracy: 0.8512
# Epoch 19/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8340 - val_loss: 0.3750 - val_accuracy: 0.8525
# Epoch 20/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8351 - val_loss: 0.3732 - val_accuracy: 0.8500
# Epoch 21/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8364 - val_loss: 0.3702 - val_accuracy: 0.8525
# Epoch 22/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8367 - val_loss: 0.3681 - val_accuracy: 0.8587
# Epoch 23/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8371 - val_loss: 0.3664 - val_accuracy: 0.8575
# Epoch 24/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8432 - val_loss: 0.3636 - val_accuracy: 0.8525
# Epoch 25/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8471 - val_loss: 0.3569 - val_accuracy: 0.8512
# Epoch 26/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3648 - accuracy: 0.8497 - val_loss: 0.3481 - val_accuracy: 0.8575
# Epoch 27/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8549 - val_loss: 0.3407 - val_accuracy: 0.8575
# Epoch 28/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8600 - val_loss: 0.3359 - val_accuracy: 0.8587
# Epoch 29/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8614 - val_loss: 0.3336 - val_accuracy: 0.8637
# Epoch 30/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8622 - val_loss: 0.3293 - val_accuracy: 0.8625
# Epoch 31/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.8632 - val_loss: 0.3301 - val_accuracy: 0.8637
# Epoch 32/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8635 - val_loss: 0.3286 - val_accuracy: 0.8675
# Epoch 33/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8629 - val_loss: 0.3289 - val_accuracy: 0.8637
# Epoch 34/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8635 - val_loss: 0.3290 - val_accuracy: 0.8637
# Epoch 35/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.3356 - accuracy: 0.8619 - val_loss: 0.3298 - val_accuracy: 0.8687
# Epoch 36/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3350 - accuracy: 0.8628 - val_loss: 0.3283 - val_accuracy: 0.8650
# Epoch 37/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.8628 - val_loss: 0.3283 - val_accuracy: 0.8662
# Epoch 38/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8635 - val_loss: 0.3287 - val_accuracy: 0.8612
# Epoch 39/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8618 - val_loss: 0.3282 - val_accuracy: 0.8637
# Epoch 40/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8622 - val_loss: 0.3282 - val_accuracy: 0.8625
# Epoch 41/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8640 - val_loss: 0.3267 - val_accuracy: 0.8662
# Epoch 42/50
# 225/225 [==============================] - 1s 3ms/step - loss: 0.3336 - accuracy: 0.8622 - val_loss: 0.3273 - val_accuracy: 0.8675
# Epoch 43/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8628 - val_loss: 0.3272 - val_accuracy: 0.8662
# Epoch 44/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8640 - val_loss: 0.3255 - val_accuracy: 0.8625
# Epoch 45/50
# 225/225 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8632 - val_loss: 0.3287 - val_accuracy: 0.8637
# Epoch 46/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8636 - val_loss: 0.3277 - val_accuracy: 0.8687
# Epoch 47/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8642 - val_loss: 0.3270 - val_accuracy: 0.8637
# Epoch 48/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8636 - val_loss: 0.3272 - val_accuracy: 0.8650
# Epoch 49/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3327 - accuracy: 0.8646 - val_loss: 0.3267 - val_accuracy: 0.8662
# Epoch 50/50
# 225/225 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8640 - val_loss: 0.3259 - val_accuracy: 0.8650

# %%
model.evaluate(x_test,y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3614 - accuracy: 0.8565
# [0.361420601606369, 0.8565000295639038]

# %%
predictions = np.round(model.predict(x_test))
predictions
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[0.],
#        [0.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %% [markdown]
# # Visualizing Accuracy and Loss

# %%
#  "Accuracy Plot"
plt.figure(figsize=(16,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss Plot"
plt.figure(figsize=(16,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# We see a lot of fluctuations in Accuracy Graph which concludes model learning is unstable

# %% [markdown]
# # Model Evaluation

# %%
#model evaluation,confusion matrix and classification report
from sklearn.metrics import accuracy_score,confusion_matrix ,classification_report
cm=confusion_matrix(y_test,predictions)
print(cm)
print(accuracy_score(y_test,predictions))
# Out:
# [[1515   63]
#  [ 224  198]]
# 0.8565

# %%
print(classification_report(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.87      0.91      1739
#          1.0       0.47      0.76      0.58       261
#
#     accuracy                           0.86      2000
#    macro avg       0.71      0.81      0.75      2000
# weighted avg       0.90      0.86      0.87      2000

# %%
import seaborn as sns

fig = plt.figure(figsize=(10,5))
confusion_matrix = cm
sns.heatmap(confusion_matrix,annot = True,fmt = 'd')
# Out:
# <AxesSubplot:>
