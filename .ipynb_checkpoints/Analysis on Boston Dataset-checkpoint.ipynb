# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("E:/SZIC AI/dataset/train.csv")
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
(data.corr()>0.4).sum()
# Out:
# Id                1
# MSSubClass        1
# LotFrontage       4
# LotArea           2
# OverallQual      13
# OverallCond       1
# YearBuilt         8
# YearRemodAdd      7
# MasVnrArea        3
# BsmtFinSF1        4
# BsmtFinSF2        1
# BsmtUnfSF         2
# TotalBsmtSF       9
# 1stFlrSF         11
# 2ndFlrSF          6
# LowQualFinSF      1
# GrLivArea        14
# BsmtFullBath      2
# BsmtHalfBath      1
# FullBath         11
# HalfBath          3
# BedroomAbvGr      4
# KitchenAbvGr      1
# TotRmsAbvGrd      8
# Fireplaces        4
# GarageYrBlt       8
# GarageCars       11
# GarageArea       10
# WoodDeckSF        1
# OpenPorchSF       1
# EnclosedPorch     1
# 3SsnPorch         1
# ScreenPorch       1
# PoolArea          1
# MiscVal           1
# MoSold            1
# YrSold            1
# SalePrice        14
# dtype: int64

# %%
fig = plt.figure(figsize=(30,25))
corr_mat = data.corr()
sns.heatmap(corr_mat,annot = True)
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Multivariate Regression

# %%
x = data[['OverallQual','1stFlrSF','GrLivArea','GarageCars','GarageArea']]
y = data[['SalePrice']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2 ,random_state = 50)

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lin.score(x_train,y_train)
# Out:
# 0.7424084533566908

# %%
lin.score(x_test,y_test)
# Out:
# 0.8351034600287877

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

# %%
polytt = poly.fit_transform(x_train)
polyt = poly.fit_transform(x_test)

# %%
lin.fit(polytt,y_train)
# Out:
# LinearRegression()

# %%
lin.score(polytt,y_train)
# Out:
# 0.8375343000998513

# %%
lin.score(polyt,y_test)
# Out:
# 0.8763058176451366

# %%
# Score for 9 features on Multivariate (Train:75% , Test:83%) test_size = 0.2
# Score for 9 features on Polynomial (Train:85% , Test:87%) test_size = 0.2
# Score for 5 features on Multivariate (Train:73% , Test:82%) test_size = 0.2
# Score for 5 features on Polynomial (Train:82% , Test:86%) test_size = 0.2
